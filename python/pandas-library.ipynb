# %%
import pandas as pd
import numpy as np
# data = pd.read_csv('')  read file of data
# data.info()  print some information about my data

# pandas is not the best extension to save data becuase it takes too lagre place in the memory
# parquet is the best then pickle (pickle saves data as binary it can save data or ai model or deep model

# to print max value in certain column
# data.temprutre.max()
data = pd.DataFrame({'X':[78,85,96,80,86], 'Y':[84,94,89,83,86],'Z':[86,97,96,72,83]}) # dataframe simliar to 2D array
print(data)
print('------------------------------------------------------------------------------------------------------------')

print(data.info())
print('------------------------------------------------------------------------------------------------------------')

print(data.X.max())
print('------------------------------------------------------------------------------------------------------------')

print(data.columns) # print columns names
print('------------------------------------------------------------------------------------------------------------')

data.loc[0][0] # print seleted elemet
print('------------------------------------------------------------------------------------------------------------')

print('First Way to print selected Column')
print(data.Y) # print selected column (diffrence if column name has a space this way will cause an error)
print('------------------------------------------------------------------------------------------------------------')

print('second Way to print selected Column')
print(data['Y'])
print('------------------------------------------------------------------------------------------------------------')

print(data.head()) #print first 5 elements
print('------------------------------------------------------------------------------------------------------------')

print(data.head(2)) #print first 2 elements
print('------------------------------------------------------------------------------------------------------------')

print(data.tail(2)) #print last 5 elements
print('------------------------------------------------------------------------------------------------------------')

print(data['Z'][2])
print('------------------------------------------------------------------------------------------------------------')

print(data[data.Z > 80].Z) # print all values over 80
print('------------------------------------------------------------------------------------------------------------')
#############################################################################################################################################
#############################################################################################################################################

# read online data
onlinedata = pd.read_csv("https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv")
print(onlinedata)

print('------------------------------------------------------------------------------------------------------------')
#############################################################################################################################################
#############################################################################################################################################

# i can convert map to dataframe
weather_data = {
    'day' : ['1/1/2107','1/2/2107','1/3/2107','1/4/2107','1/5/2107','1/6/2107'],
    'temperature' : [32,35,28,24,32,31],
    'windspeed' : [6,7,2,7,4,2],
    'evvent' : ['Rain','Sunny','Snow','Snow','Sunny','Sunny']
}
df = pd.DataFrame(weather_data)
print(df)
print('------------------------------------------------------------------------------------------------------------')

print(df['temperature'].mean())
print('------------------------------------------------------------------------------------------------------------')

print(df['temperature'].std())
print('------------------------------------------------------------------------------------------------------------')

print(df['day'][df['temperature'] == df['temperature'].min()]) # get day with minimum temperature
print('------------------------------------------------------------------------------------------------------------')

df.set_index('day',inplace=True) # change index 
print(df)
print('------------------------------------------------------------------------------------------------------------')

df['NewData'] = np.arange(1,7)# add new column
print(df)
print('------------------------------------------------------------------------------------------------------------')

df.drop('NewData' , inplace=True , axis = 1) # reomve column , (axis 1 column , axis 0 row)
print(df)
print('------------------------------------------------------------------------------------------------------------')

#############################################################################################################################################
#############################################################################################################################################

#read from excel

data_frame = pd.read_excel('/kaggle/input/d/abdelrhmannashaat/pracrice-pandas/data.xlsx') 
print(data_frame)
print('------------------------------------------------------------------------------------------------------------')

data_frame.drop('Unnamed: 0', axis=1)
# write on excel 
# with pd.ExcelWriter('excel name') as writer : 
# df.to_excel(writer,sheet_name  = '')

#############################################################################################################################################
#############################################################################################################################################

# handlling missing data
new_data = pd.read_csv('/kaggle/input/d/abdelrhmannashaat/pracrice-pandas/weather_data.csv') 
print(new_data)
print('------------------------------------------------------------------------------------------------------------')

new_data1 = new_data.fillna(0)
print(new_data1)
print('------------------------------------------------------------------------------------------------------------')

new_data2 = new_data.fillna(method='ffill') # fill nan with previous value
print(new_data2)
print('------------------------------------------------------------------------------------------------------------')

new_data3 = new_data.fillna(method='bfill') # fill nan with next value
print(new_data3)
print('------------------------------------------------------------------------------------------------------------')

new_data4 = new_data.interpolate() # make pandas excpect missing values
print(new_data4)
print('------------------------------------------------------------------------------------------------------------') 

#############################################################################################################################################
#############################################################################################################################################
# group by

data1 = pd.read_csv('/kaggle/input/d/abdelrhmannashaat/pracrice-pandas/weather_by_cities.csv') 
print(data1)
print('------------------------------------------------------------------------------------------------------------')

groups = data1.groupby("city")
print(groups)
print('------------------------------------------------------------------------------------------------------------')

print(groups.describe())
# Out:
#     X   Y   Z
# 0  78  84  86
# 1  85  94  97
# 2  96  89  96
# 3  80  83  72
# 4  86  86  83
# ------------------------------------------------------------------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X       5 non-null      int64
#  1   Y       5 non-null      int64
#  2   Z       5 non-null      int64
# dtypes: int64(3)
# memory usage: 248.0 bytes
# None
# ------------------------------------------------------------------------------------------------------------
# 96
# ------------------------------------------------------------------------------------------------------------
# Index(['X', 'Y', 'Z'], dtype='object')
# ------------------------------------------------------------------------------------------------------------
# ...
