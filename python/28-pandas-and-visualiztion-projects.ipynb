# %%
import pandas as pd

# %%
# 01_Getting_&_Knowing_Your_Data

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname,filename))
# Out:
# /kaggle/input/en.openfoodfacts.org.products.tsv

# %%
# World Food Facts

# %%
food_data = pd.read_csv('/kaggle/input/en.openfoodfacts.org.products.tsv',delimiter='\t')
food_df = pd.DataFrame(food_data)
food_df
# Out:
# /tmp/ipykernel_47/2989719518.py:1: DtypeWarning: Columns (0,3,5,19,20,24,25,26,27,28,36,37,38,39,48) have mixed types. Specify dtype option on import or set low_memory=False.
#   food_data = pd.read_csv('/kaggle/input/en.openfoodfacts.org.products.tsv',delimiter='\t')
#                  code                                                url  \
# 0                3087  http://world-en.openfoodfacts.org/product/0000...
# 1                4530  http://world-en.openfoodfacts.org/product/0000...
# 2                4559  http://world-en.openfoodfacts.org/product/0000...
# 3               16087  http://world-en.openfoodfacts.org/product/0000...
# 4               16094  http://world-en.openfoodfacts.org/product/0000...
# ...               ...                                                ...
# 356022       99567453  http://world-en.openfoodfacts.org/product/9956...
# 356023  9970229501521  http://world-en.openfoodfacts.org/product/9970...
# ...

# %%
# See the first 5 entries
food_df.head()
# Out:
#     code                                                url  \
# 0   3087  http://world-en.openfoodfacts.org/product/0000...
# 1   4530  http://world-en.openfoodfacts.org/product/0000...
# 2   4559  http://world-en.openfoodfacts.org/product/0000...
# 3  16087  http://world-en.openfoodfacts.org/product/0000...
# 4  16094  http://world-en.openfoodfacts.org/product/0000...
#
#                       creator   created_t      created_datetime  \
# 0  openfoodfacts-contributors  1474103866  2016-09-17T09:17:46Z
# 1             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 2             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 3             usda-ndb-import  1489055731  2017-03-09T10:35:31Z
# 4             usda-ndb-import  1489055653  2017-03-09T10:34:13Z
#
#   last_modified_t last_modified_datetime                    product_name  \
# 0      1474103893   2016-09-17T09:18:13Z              Farine de blé noir
# ...

# %%
# What is the number of observations in the dataset?
num_observations = len(food_df) 
print(num_observations)
# Out:
# 356027

# %%
# What is the number of columns in the dataset?
num_columns = food_df.shape[1] 
print(num_columns)
# Out:
# 163

# %%
#Print the name of all the columns
food_df.columns
# Out:
# Index(['code', 'url', 'creator', 'created_t', 'created_datetime',
#        'last_modified_t', 'last_modified_datetime', 'product_name',
#        'generic_name', 'quantity',
#        ...
#        'fruits-vegetables-nuts_100g', 'fruits-vegetables-nuts-estimate_100g',
#        'collagen-meat-protein-ratio_100g', 'cocoa_100g', 'chlorophyl_100g',
#        'carbon-footprint_100g', 'nutrition-score-fr_100g',
#        'nutrition-score-uk_100g', 'glycemic-index_100g',
#        'water-hardness_100g'],
#       dtype='object', length=163)

# %%
# What is the name of 105th column?
column_name_105 = food_df.columns[104] 
print(column_name_105)
# Out:
# -glucose_100g

# %%
# What is the type of the observations of the 105th column?
column_105_type = food_df.dtypes[104]
print(column_105_type)
# Out:
# float64

# %%
# How is the dataset indexed?
print(food_df.index)
# Out:
# RangeIndex(start=0, stop=356027, step=1)

# %%
# What is the product name of the 19th observation?
product_name = food_df.loc[18,'product_name'] 
print(product_name)
# Out:
# Lotus Organic Brown Jasmine Rice

# %%
# New Project

# %%
# Occupation
users_df = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user')
users_df.columns
users_df['user_id|age|gender|occupation|zip_code'] = users_df['user_id|age|gender|occupation|zip_code'].str.split('|')
users_df[['user_id', 'age', 'gender', 'occupation', 'zip_code']] = pd.DataFrame(users_df['user_id|age|gender|occupation|zip_code'].tolist(), index=users_df.index)
users_df = users_df.drop(columns=['user_id|age|gender|occupation|zip_code'])
users_df
# Out:
#     user_id age gender     occupation zip_code
# 0         1  24      M     technician    85711
# 1         2  53      F          other    94043
# 2         3  23      M         writer    32067
# 3         4  24      M     technician    43537
# 4         5  33      F          other    15213
# ..      ...  ..    ...            ...      ...
# 938     939  26      F        student    33319
# 939     940  32      M  administrator    02215
# 940     941  20      M        student    97229
# 941     942  48      F      librarian    78209
# 942     943  22      M        student    77841
#
# [943 rows x 5 columns]

# %%
# See the first 25 entries
users_df.head(25)
# Out:
#    user_id age gender     occupation zip_code
# 0        1  24      M     technician    85711
# 1        2  53      F          other    94043
# 2        3  23      M         writer    32067
# 3        4  24      M     technician    43537
# 4        5  33      F          other    15213
# 5        6  42      M      executive    98101
# 6        7  57      M  administrator    91344
# 7        8  36      M  administrator    05201
# 8        9  29      M        student    01002
# 9       10  53      M         lawyer    90703
# 10      11  39      F          other    30329
# 11      12  28      F          other    06405
# 12      13  47      M       educator    29206
# 13      14  45      M      scientist    55106
# 14      15  49      F       educator    97301
# 15      16  21      M  entertainment    10309
# 16      17  30      M     programmer    06355
# 17      18  35      F          other    37212
# 18      19  40      M      librarian    02138
# ...

# %%
# See the last 10 entries
users_df.tail(10)
# Out:
#     user_id age gender     occupation zip_code
# 933     934  61      M       engineer    22902
# 934     935  42      M         doctor    66221
# 935     936  24      M          other    32789
# 936     937  48      M       educator    98072
# 937     938  38      F     technician    55038
# 938     939  26      F        student    33319
# 939     940  32      M  administrator    02215
# 940     941  20      M        student    97229
# 941     942  48      F      librarian    78209
# 942     943  22      M        student    77841

# %%
# What is the number of observations in the dataset?
num_observations = len(users_df) 
print(num_observations)
# Out:
# 943

# %%
# What is the number of columns in the dataset?
number_of_columns = users_df.shape[1]
print(number_of_columns)
# Out:
# 5

# %%
# Print the name of all the columns
users_df.columns
# Out:
# Index(['user_id', 'age', 'gender', 'occupation', 'zip_code'], dtype='object')

# %%
# How is the dataset indexed?
print(users_df.index)
# Out:
# RangeIndex(start=0, stop=943, step=1)

# %%
# What is the data type of each column?
users_df.dtypes
# Out:
# user_id       object
# age           object
# gender        object
# occupation    object
# zip_code      object
# dtype: object

# %%
# Print only the occupation column
users_df['occupation']
# Out:
# 0         technician
# 1              other
# 2             writer
# 3         technician
# 4              other
#            ...
# 938          student
# 939    administrator
# 940          student
# 941        librarian
# 942          student
# Name: occupation, Length: 943, dtype: object

# %%
# How many different occupations are in this dataset?
users_df['occupation'].nunique()
# Out:
# 21

# %%
# What is the most frequent occupation?
users_df['occupation'].value_counts().idxmax()
# Out:
# 'student'

# %%
# Summarize the DataFrame
users_df.describe()
# Out:
#        user_id  age gender occupation zip_code
# count      943  943    943        943      943
# unique     943   61      2         21      795
# top          1   30      M    student    55414
# freq         1   39    670        196        9

# %%
# New Project

# %%
# Chipotle
chipo = pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv",delimiter='\t')
chipo_df = pd.DataFrame(chipo)
chipo_df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
# See the first 10 entries
chipo_df.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
# What is the number of observations in the dataset?
print(len(chipo_df))
# Out:
# 4622

# %%
# What is the number of columns in the dataset?
print(chipo_df.shape[1])
# Out:
# 5

# %%
# What is the number of columns in the dataset?
chipo_df.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
# How is the dataset indexed?
print(chipo_df.index)
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
# Which was the most-ordered item? 
most_ordered_item = chipo_df['item_name'].value_counts().idxmax()
most_ordered_item
# Out:
# 'Chicken Bowl'

# %%
# For the most-ordered item, how many items were ordered?
item_counts = chipo_df['item_name'].value_counts()
quantity_ordered = item_counts.max()
print(quantity_ordered)
# Out:
# 726

# %%
# What was the most ordered item in the choice_description column?
chipo_df['choice_description'].value_counts().idxmax()
# Out:
# '[Diet Coke]'

# %%
# How many items were orderd in total?
len(chipo_df['item_name'])
# Out:
# 4622

# %%
# Turn the item price into a float
chipo_df['item_price'] = chipo_df['item_price'].str[1:].astype(float)

# %%
# Check the item price type
print(chipo_df['item_price'].dtypes)
# Out:
# float64

# %%
# Create a lambda function and change the type of item price
chipo_df['item_price'] = chipo_df['item_price'].apply(lambda x: float(x))

# %%
# Check the item price type
print(chipo_df['item_price'].dtypes)
# Out:
# float64

# %%
# How much was the revenue for the period in the dataset?
chipo_df['revenue'] = chipo_df['item_price'] * chipo_df['item_price']
print("{:.3f}".format(chipo_df['revenue'].sum()))
# Out:
# 340813.176

# %%
# How many orders were made in the period?
print(chipo_df['order_id'].nunique())
# Out:
# 1834

# %%
# What is the average revenue amount per order?
average_revenue_per_order = chipo_df['revenue'].sum() / chipo_df['order_id'].nunique()
print("{:.3f}".format(average_revenue_per_order))
# Out:
# 185.831

# %%
# How many different items are sold?
items = chipo_df['item_name'].unique()
items_df = pd.DataFrame(items)
items_df
# Out:
#                                         0
# 0            Chips and Fresh Tomato Salsa
# 1                                    Izze
# 2                        Nantucket Nectar
# 3   Chips and Tomatillo-Green Chili Salsa
# 4                            Chicken Bowl
# 5                           Side of Chips
# 6                           Steak Burrito
# 7                        Steak Soft Tacos
# 8                     Chips and Guacamole
# 9                    Chicken Crispy Tacos
# 10                     Chicken Soft Tacos
# 11                        Chicken Burrito
# 12                            Canned Soda
# 13                       Barbacoa Burrito
# 14                       Carnitas Burrito
# 15                          Carnitas Bowl
# 16                          Bottled Water
# 17  Chips and Tomatillo Green Chili Salsa
# 18                          Barbacoa Bowl
# 19                                  Chips
# 20                     Chicken Salad Bowl
# ...

# %%
# New Section

# %%
# 02_Filtering_&_Sorting

# %%
# Fictional Army

raw_data = {'regiment': ['Nighthawks', 'Nighthawks', 'Nighthawks', 'Nighthawks', 'Dragoons', 'Dragoons', 'Dragoons', 'Dragoons', 'Scouts', 'Scouts', 'Scouts', 'Scouts'],
            'company': ['1st', '1st', '2nd', '2nd', '1st', '1st', '2nd', '2nd','1st', '1st', '2nd', '2nd'],
            'deaths': [523, 52, 25, 616, 43, 234, 523, 62, 62, 73, 37, 35],
            'battles': [5, 42, 2, 2, 4, 7, 8, 3, 4, 7, 8, 9],
            'size': [1045, 957, 1099, 1400, 1592, 1006, 987, 849, 973, 1005, 1099, 1523],
            'veterans': [1, 5, 62, 26, 73, 37, 949, 48, 48, 435, 63, 345],
            'readiness': [1, 2, 3, 3, 2, 1, 2, 3, 2, 1, 2, 3],
            'armored': [1, 0, 1, 1, 0, 1, 0, 1, 0, 0, 1, 1],
            'deserters': [4, 24, 31, 2, 3, 4, 24, 31, 2, 3, 2, 3],
            'origin': ['Arizona', 'California', 'Texas', 'Florida', 'Maine', 'Iowa', 'Alaska', 'Washington', 'Oregon', 'Wyoming', 'Louisana', 'Georgia']}
army_df = pd.DataFrame(raw_data)

# %%
# Set the 'origin' colum as the index of the dataframe

army_df.set_index('origin', inplace=True)
army_df
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st     523        5  1045         1          1
# California  Nighthawks     1st      52       42   957         5          2
# Texas       Nighthawks     2nd      25        2  1099        62          3
# Florida     Nighthawks     2nd     616        2  1400        26          3
# Maine         Dragoons     1st      43        4  1592        73          2
# Iowa          Dragoons     1st     234        7  1006        37          1
# Alaska        Dragoons     2nd     523        8   987       949          2
# Washington    Dragoons     2nd      62        3   849        48          3
# Oregon          Scouts     1st      62        4   973        48          2
# Wyoming         Scouts     1st      73        7  1005       435          1
# Louisana        Scouts     2nd      37        8  1099        63          2
# ...

# %%
# Print only the column veterans
army_df[['veterans']]
# Out:
#             veterans
# origin
# Arizona            1
# California         5
# Texas             62
# Florida           26
# Maine             73
# Iowa              37
# Alaska           949
# Washington        48
# Oregon            48
# Wyoming          435
# Louisana          63
# Georgia          345

# %%
# Print the columns 'veterans' and 'deaths'
army_df[['veterans','deaths']]
# Out:
#             veterans  deaths
# origin
# Arizona            1     523
# California         5      52
# Texas             62      25
# Florida           26     616
# Maine             73      43
# Iowa              37     234
# Alaska           949     523
# Washington        48      62
# Oregon            48      62
# Wyoming          435      73
# Louisana          63      37
# Georgia          345      35

# %%
# Print the name of all the columns
army_df.columns
# Out:
# Index(['regiment', 'company', 'deaths', 'battles', 'size', 'veterans',
#        'readiness', 'armored', 'deserters'],
#       dtype='object')

# %%
# Select the 'deaths', 'size' and 'deserters' columns from Maine and Alaska
army_df.loc[['Maine', 'Alaska'],['deaths','size','deserters']]
# Out:
#         deaths  size  deserters
# origin
# Maine       43  1592          3
# Alaska     523   987         24

# %%
# Select the rows 3 to 7 and the columns 3 to 6
army_df.iloc[2:7, 2:6]
# Out:
#          deaths  battles  size  veterans
# origin
# Texas        25        2  1099        62
# Florida     616        2  1400        26
# Maine        43        4  1592        73
# Iowa        234        7  1006        37
# Alaska      523        8   987       949

# %%
# Select every row after the fourth row and all columns
army_df.iloc[4:, :]
# Out:
#             regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Maine       Dragoons     1st      43        4  1592        73          2
# Iowa        Dragoons     1st     234        7  1006        37          1
# Alaska      Dragoons     2nd     523        8   987       949          2
# Washington  Dragoons     2nd      62        3   849        48          3
# Oregon        Scouts     1st      62        4   973        48          2
# Wyoming       Scouts     1st      73        7  1005       435          1
# Louisana      Scouts     2nd      37        8  1099        63          2
# Georgia       Scouts     2nd      35        9  1523       345          3
#
#             armored  deserters
# origin
# Maine             0          3
# Iowa              1          4
# Alaska            0         24
# Washington        1         31
# Oregon            0          2
# Wyoming           0          3
# Louisana          1          2
# Georgia           1          3

# %%
# Select every row up to the 4th row and all columns
army_df.iloc[:4, :]
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st     523        5  1045         1          1
# California  Nighthawks     1st      52       42   957         5          2
# Texas       Nighthawks     2nd      25        2  1099        62          3
# Florida     Nighthawks     2nd     616        2  1400        26          3
#
#             armored  deserters
# origin
# Arizona           1          4
# California        0         24
# Texas             1         31
# Florida           1          2

# %%
# Select the 3rd column up to the 7th column
army_df.iloc[: ,3:7]
# Out:
#             battles  size  veterans  readiness
# origin
# Arizona           5  1045         1          1
# California       42   957         5          2
# Texas             2  1099        62          3
# Florida           2  1400        26          3
# Maine             4  1592        73          2
# Iowa              7  1006        37          1
# Alaska            8   987       949          2
# Washington        3   849        48          3
# Oregon            4   973        48          2
# Wyoming           7  1005       435          1
# Louisana          8  1099        63          2
# Georgia           9  1523       345          3

# %%
# Select rows where df.deaths is greater than 50
army_df[army_df['deaths'] > 50 ]
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st     523        5  1045         1          1
# California  Nighthawks     1st      52       42   957         5          2
# Florida     Nighthawks     2nd     616        2  1400        26          3
# Iowa          Dragoons     1st     234        7  1006        37          1
# Alaska        Dragoons     2nd     523        8   987       949          2
# Washington    Dragoons     2nd      62        3   849        48          3
# Oregon          Scouts     1st      62        4   973        48          2
# Wyoming         Scouts     1st      73        7  1005       435          1
#
#             armored  deserters
# origin
# Arizona           1          4
# California        0         24
# Florida           1          2
# Iowa              1          4
# Alaska            0         24
# Washington        1         31
# Oregon            0          2
# ...

# %%
# Select rows where df.deaths is greater than 500 or less than 50
army_df[army_df['deaths'] > 50 ]
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st     523        5  1045         1          1
# California  Nighthawks     1st      52       42   957         5          2
# Florida     Nighthawks     2nd     616        2  1400        26          3
# Iowa          Dragoons     1st     234        7  1006        37          1
# Alaska        Dragoons     2nd     523        8   987       949          2
# Washington    Dragoons     2nd      62        3   849        48          3
# Oregon          Scouts     1st      62        4   973        48          2
# Wyoming         Scouts     1st      73        7  1005       435          1
#
#             armored  deserters
# origin
# Arizona           1          4
# California        0         24
# Florida           1          2
# Iowa              1          4
# Alaska            0         24
# Washington        1         31
# Oregon            0          2
# ...

# %%
# Select rows where df.deaths is greater than 500 or less than 50
army_df[(army_df['deaths'] > 500) | (army_df['deaths'] < 50)]
# Out:
#             regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona   Nighthawks     1st     523        5  1045         1          1
# Texas     Nighthawks     2nd      25        2  1099        62          3
# Florida   Nighthawks     2nd     616        2  1400        26          3
# Maine       Dragoons     1st      43        4  1592        73          2
# Alaska      Dragoons     2nd     523        8   987       949          2
# Louisana      Scouts     2nd      37        8  1099        63          2
# Georgia       Scouts     2nd      35        9  1523       345          3
#
#           armored  deserters
# origin
# Arizona         1          4
# Texas           1         31
# Florida         1          2
# Maine           0          3
# Alaska          0         24
# Louisana        1          2
# Georgia         1          3

# %%
# Select all the regiments not named "Dragoons"
army_df[(army_df['regiment'] != 'Dragoons')][['regiment']]
# Out:
#               regiment
# origin
# Arizona     Nighthawks
# California  Nighthawks
# Texas       Nighthawks
# Florida     Nighthawks
# Oregon          Scouts
# Wyoming         Scouts
# Louisana        Scouts
# Georgia         Scouts

# %%
# Select the rows called Texas and Arizona
army_df.loc[['Texas', 'Arizona']]
# Out:
#            regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Texas    Nighthawks     2nd      25        2  1099        62          3
# Arizona  Nighthawks     1st     523        5  1045         1          1
#
#          armored  deserters
# origin
# Texas          1         31
# Arizona        1          4

# %%
# Select the third cell in the row named Arizona
army_df.loc['Arizona'].iloc[2]
# Out:
# 523

# %%
# Select the third cell down in the column named deaths
army_df['deaths'].iloc[-3]
# Out:
# 73

# %%
# New Project

# %%
# Euro12

# %%
euro12_df = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv')
euro12_df
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
euro12_df[['Goals']]
# Out:
#     Goals
# 0       4
# 1       4
# 2       4
# 3       5
# 4       3
# 5      10
# 6       5
# 7       6
# 8       2
# 9       2
# 10      6
# 11      1
# 12      5
# 13     12
# 14      5
# 15      2

# %%
# How many team participated in the Euro2012?
len(euro12_df['Team'])
# Out:
# 16

# %%
# What is the number of columns in the dataset?
euro12_df.shape[1]
# Out:
# 35

# %%
# View only the columns Team, Yellow Cards and Red Cards and assign them to a dataframe called discipline
euro12_df[['Team','Yellow Cards','Red Cards']]
# Out:
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 6                Greece             9          1
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 9                Poland             7          1
# 10             Portugal            12          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %%
# Sort the teams by Red Cards, then to Yellow Cards
sorted_teams = euro12_df.sort_values(by=['Red Cards','Yellow Cards'])
sorted_teams
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 2               Denmark      4               10                10
# 5               Germany     10               32                32
# 3               England      5               11                18
# 8           Netherlands      2               12                36
# 15              Ukraine      2                7                26
# 4                France      3               22                24
# 12               Russia      5                9                31
# 1        Czech Republic      4               13                18
# 14               Sweden      5               17                19
# 0               Croatia      4               13                12
# 13                Spain     12               42                33
# 10             Portugal      6               22                42
# 7                 Italy      6               34                45
# ...

# %%
# Calculate the mean Yellow Cards given per Team
mean_yellow_cards = euro12_df.groupby('Team')['Yellow Cards'].mean()
pd.DataFrame(mean_yellow_cards)
# Out:
#                      Yellow Cards
# Team
# Croatia                       9.0
# Czech Republic                7.0
# Denmark                       4.0
# England                       5.0
# France                        6.0
# Germany                       4.0
# Greece                        9.0
# Italy                        16.0
# Netherlands                   5.0
# Poland                        7.0
# Portugal                     12.0
# Republic of Ireland           6.0
# Russia                        6.0
# Spain                        11.0
# Sweden                        7.0
# Ukraine                       5.0

# %%
# Filter teams that scored more than 6 goals
euro12_df[euro12_df['Goals'] > 6 ][['Team']]
# Out:
#        Team
# 5   Germany
# 13    Spain

# %%
# Select the teams that start with G
euro12_df[euro12_df['Team'].str.startswith('G')][['Team']]
# Out:
#       Team
# 5  Germany
# 6   Greece

# %%
# Select the first 7 columns
euro12_df.iloc[: , :7]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
# Select all columns except the last 3
euro12_df.iloc[: , :-3]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
# Present only the Shooting Accuracy from England, Italy and Russia 
euro12_df.set_index('Team', inplace=True)
euro12_df.loc[['England','Italy','Russia'],['Shooting Accuracy']]
# Out:
#         Shooting Accuracy
# Team
# England             50.0%
# Italy               43.0%
# Russia              22.5%

# %%
# New Project

# %%
# Chipotle
chipo_df = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv',delimiter='\t')
chipo_df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
# What is the price of each item? 
chipo_df[['item_name','item_price']]
# Out:
#                                   item_name item_price
# 0              Chips and Fresh Tomato Salsa     $2.39
# 1                                      Izze     $3.39
# 2                          Nantucket Nectar     $3.39
# 3     Chips and Tomatillo-Green Chili Salsa     $2.39
# 4                              Chicken Bowl    $16.98
# ...                                     ...        ...
# 4617                          Steak Burrito    $11.75
# 4618                          Steak Burrito    $11.75
# 4619                     Chicken Salad Bowl    $11.25
# 4620                     Chicken Salad Bowl     $8.75
# 4621                     Chicken Salad Bowl     $8.75
#
# [4622 rows x 2 columns]

# %%
# How many products cost more than $10.00
len(chipo[chipo['item_price'].str[1:].astype(float) > 10])
# Out:
# 1130

# %%
# Sort by the name of the item
sorted_names = chipo_df.sort_values(by=['item_name'])
sorted_names
# Out:
#       order_id  quantity          item_name  \
# 3389      1360         2  6 Pack Soft Drink
# 341        148         1  6 Pack Soft Drink
# 1849       749         1  6 Pack Soft Drink
# 1860       754         1  6 Pack Soft Drink
# 2713      1076         1  6 Pack Soft Drink
# ...        ...       ...                ...
# 2384       948         1  Veggie Soft Tacos
# 781        322         1  Veggie Soft Tacos
# 2851      1132         1  Veggie Soft Tacos
# 1699       688         1  Veggie Soft Tacos
# 1395       567         1  Veggie Soft Tacos
#
#                                      choice_description item_price
# 3389                                        [Diet Coke]    $12.98
# 341                                         [Diet Coke]     $6.49
# 1849                                             [Coke]     $6.49
# 1860                                        [Diet Coke]     $6.49
# 2713                                             [Coke]     $6.49
# ...

# %%
# What was the quantity of the most expensive item ordered?
chipo_df['item_price'] = chipo_df['item_price'].replace('[\$,]', '', regex=True).astype(float)
max_price_index = chipo_df['item_price'].idxmax()
chipo_df.loc[max_price_index, 'quantity']
# Out:
# 15

# %%
# How many times was a Veggie Salad Bowl ordered?
len(chipo_df[chipo_df['item_name'] == 'Veggie Salad Bowl'])
# Out:
# 18

# %%
# How many times did someone order more than one Canned Soda?
filterd_df = chipo_df[(chipo_df['item_name'] == 'Canned Soda') & (chipo_df['quantity'] > 1)]
len(filterd_df)
# Out:
# 20

# %%
# New Section

# %%
# 03_Grouping

# %%
# Regiment
raw_data = {'regiment': ['Nighthawks', 'Nighthawks', 'Nighthawks', 'Nighthawks', 'Dragoons', 'Dragoons', 'Dragoons', 'Dragoons', 'Scouts', 'Scouts', 'Scouts', 'Scouts'], 
        'company': ['1st', '1st', '2nd', '2nd', '1st', '1st', '2nd', '2nd','1st', '1st', '2nd', '2nd'], 
        'name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze', 'Jacon', 'Ryaner', 'Sone', 'Sloan', 'Piger', 'Riani', 'Ali'], 
        'preTestScore': [4, 24, 31, 2, 3, 4, 24, 31, 2, 3, 2, 3],
        'postTestScore': [25, 94, 57, 62, 70, 25, 94, 57, 62, 70, 62, 70]}

regiment_df = pd.DataFrame(raw_data)
regiment_df
# Out:
#       regiment company      name  preTestScore  postTestScore
# 0   Nighthawks     1st    Miller             4             25
# 1   Nighthawks     1st  Jacobson            24             94
# 2   Nighthawks     2nd       Ali            31             57
# 3   Nighthawks     2nd    Milner             2             62
# 4     Dragoons     1st     Cooze             3             70
# 5     Dragoons     1st     Jacon             4             25
# 6     Dragoons     2nd    Ryaner            24             94
# 7     Dragoons     2nd      Sone            31             57
# 8       Scouts     1st     Sloan             2             62
# 9       Scouts     1st     Piger             3             70
# 10      Scouts     2nd     Riani             2             62
# 11      Scouts     2nd       Ali             3             70

# %%
#  What is the mean preTestScore from the regiment Nighthawks?  
regiment_df[regiment_df['regiment'] == 'Nighthawks']['preTestScore'].mean()
# Out:
# 15.25

# %%
# Present general statistics by company
statistics_by_company = regiment_df.groupby('company')
statistics_by_company.describe()
# Out:
#         preTestScore                                                      \
#                count       mean        std  min   25%   50%    75%   max
# company
# 1st              6.0   6.666667   8.524475  2.0  3.00   3.5   4.00  24.0
# 2nd              6.0  15.500000  14.652645  2.0  2.25  13.5  29.25  31.0
#
#         postTestScore
#                 count       mean        std   min    25%   50%   75%   max
# company
# 1st               6.0  57.666667  27.485754  25.0  34.25  66.0  70.0  94.0
# 2nd               6.0  67.000000  14.057027  57.0  58.25  62.0  68.0  94.0

# %%
# What is the mean of each company's preTestScore ? 
mean_pretest_by_company = regiment_df.groupby('company')['preTestScore'].mean()
mean_pretest_by_company_df = pd.DataFrame(mean_pretest_by_company)
mean_pretest_by_company_df
# Out:
#          preTestScore
# company
# 1st          6.666667
# 2nd         15.500000

# %%
# Present the mean preTestScores grouped by regiment and company 
regiment_df.groupby(['regiment','company'])['preTestScore'].mean()
# Out:
# regiment    company
# Dragoons    1st         3.5
#             2nd        27.5
# Nighthawks  1st        14.0
#             2nd        16.5
# Scouts      1st         2.5
#             2nd         2.5
# Name: preTestScore, dtype: float64

# %%
# Present the mean preTestScores grouped by regiment and company without heirarchical indexing
regiment_df.groupby(['regiment','company'])['preTestScore'].mean().reset_index(drop=True)
# Out:
# 0     3.5
# 1    27.5
# 2    14.0
# 3    16.5
# 4     2.5
# 5     2.5
# Name: preTestScore, dtype: float64

# %%
# Group the entire dataframe by regiment and company
grouped_df = regiment_df.groupby(['regiment','company'])
for group, group_data in grouped_df:
    print(f"\nGroup: {group}")
    print(group_data)
# Out:
# Group: ('Dragoons', '1st')
#    regiment company   name  preTestScore  postTestScore
# 4  Dragoons     1st  Cooze             3             70
# 5  Dragoons     1st  Jacon             4             25
#
# Group: ('Dragoons', '2nd')
#    regiment company    name  preTestScore  postTestScore
# 6  Dragoons     2nd  Ryaner            24             94
# 7  Dragoons     2nd    Sone            31             57
#
# Group: ('Nighthawks', '1st')
#      regiment company      name  preTestScore  postTestScore
# 0  Nighthawks     1st    Miller             4             25
# 1  Nighthawks     1st  Jacobson            24             94
#
# Group: ('Nighthawks', '2nd')
#      regiment company    name  preTestScore  postTestScore
# 2  Nighthawks     2nd     Ali            31             57
# 3  Nighthawks     2nd  Milner             2             62
#
# Group: ('Scouts', '1st')
#   regiment company   name  preTestScore  postTestScore
# 8   Scouts     1st  Sloan             2             62
# ...

# %%
# What is the number of observations in each regiment and company
regiment_df.shape[0]
# Out:
# 12

# %%
# Iterate over a group and print the name and the whole data from the regiment
for group_name, group_data in grouped_df:
    print(f"\nGroup Name: {group_name}")
    print(group_data)
# Out:
# Group Name: ('Dragoons', '1st')
#    regiment company   name  preTestScore  postTestScore
# 4  Dragoons     1st  Cooze             3             70
# 5  Dragoons     1st  Jacon             4             25
#
# Group Name: ('Dragoons', '2nd')
#    regiment company    name  preTestScore  postTestScore
# 6  Dragoons     2nd  Ryaner            24             94
# 7  Dragoons     2nd    Sone            31             57
#
# Group Name: ('Nighthawks', '1st')
#      regiment company      name  preTestScore  postTestScore
# 0  Nighthawks     1st    Miller             4             25
# 1  Nighthawks     1st  Jacobson            24             94
#
# Group Name: ('Nighthawks', '2nd')
#      regiment company    name  preTestScore  postTestScore
# 2  Nighthawks     2nd     Ali            31             57
# 3  Nighthawks     2nd  Milner             2             62
#
# Group Name: ('Scouts', '1st')
#   regiment company   name  preTestScore  postTestScore
# ...

# %%
# New Project

# %%
# Occupation
users_df
# Out:
#     user_id age gender     occupation zip_code
# 0         1  24      M     technician    85711
# 1         2  53      F          other    94043
# 2         3  23      M         writer    32067
# 3         4  24      M     technician    43537
# 4         5  33      F          other    15213
# ..      ...  ..    ...            ...      ...
# 938     939  26      F        student    33319
# 939     940  32      M  administrator    02215
# 940     941  20      M        student    97229
# 941     942  48      F      librarian    78209
# 942     943  22      M        student    77841
#
# [943 rows x 5 columns]

# %%
# Discover what is the mean age per occupation
mean_age_per_occupation = users_df.groupby('occupation')['age'].mean()
mean_age_per_occupation_df = pd.DataFrame(mean_age_per_occupation)
mean_age_per_occupation_df
# Out:
#                                                              age
# occupation
# administrator  7261244361107375986148181394636878370702688856...
# artist         1079015194101614427140190784657937429246232676...
# doctor                                      6611850208063.142578
# educator       4999247297384380064916222626366165804911675524...
# engineer       5894527797421578530515682567192733810632210619...
# entertainment              11895795728624073838975941873762304.0
# executive      1319476515426477012898889786046393759903315879...
# healthcare                     3150297091390539085991483801600.0
# homemaker                                        6029033609289.0
# lawyer                                 44419042061274482475008.0
# librarian      7922142254007916905213626081624135648697091237...
# marketing      1058967509370598276107550909438641643219727260...
# none                                         18146705683903628.0
# ...

# %%
# Discover the Male ratio per occupation and sort it from the most to the least
male_ratio_per_occupation = users_df.groupby('occupation')['age'].count()
male_ratio_per_occupation_df = pd.DataFrame(male_ratio_per_occupation)
male_ratio_per_occupation_df
# Out:
#                age
# occupation
# administrator   79
# artist          28
# doctor           7
# educator        95
# engineer        67
# entertainment   18
# executive       32
# healthcare      16
# homemaker        7
# lawyer          12
# librarian       51
# marketing       26
# none             9
# other          105
# programmer      66
# retired         14
# salesman        12
# scientist       31
# student        196
# technician      27
# writer          45

# %%
# For each occupation, calculate the minimum and maximum ages
minimum = users_df.groupby('occupation')['age'].min()
maximum = users_df.groupby('occupation')['age'].max()
minimum_df = pd.DataFrame(minimum)
maximum_df = pd.DataFrame(maximum)

# %%
minimum_df
# Out:
#               age
# occupation
# administrator  21
# artist         19
# doctor         28
# educator       23
# engineer       22
# entertainment  15
# executive      22
# healthcare     22
# homemaker      20
# lawyer         21
# librarian      23
# marketing      24
# none           11
# other          13
# programmer     20
# retired        51
# salesman       18
# scientist      23
# student        10
# technician     21
# writer         18

# %%
maximum_df
# Out:
#               age
# occupation
# administrator  70
# artist         48
# doctor         64
# educator       63
# engineer       70
# entertainment  50
# executive      69
# healthcare     62
# homemaker      50
# lawyer         53
# librarian      69
# marketing      55
# none           55
# other          64
# programmer     63
# retired        73
# salesman       66
# scientist      55
# student         7
# technician     55
# writer         60

# %%
# For each combination of occupation and gender, calculate the mean age
combination_of_occupation_and_gender = users_df.groupby(['occupation','gender'])['age'].mean()
combination_of_occupation_and_gender_df = pd.DataFrame(combination_of_occupation_and_gender)
combination_of_occupation_and_gender_df
# Out:
#                                                                     age
# occupation    gender
# administrator F       1063189981787760575100878301754419220372412750...
#               M       1334024308433658334492062346236555583403805174...
# artist        F                             2324042169540791647600640.0
#               M                         16289683549288850225037836288.0
# doctor        M                                    6611850208063.142578
# educator      F       1904359554359588742882260651234669875766738970...
#               M       6852888770441231765086718976968888035959609704...
# engineer      F                                                  1811.5
#               M       6075897883496088256705947512789509179373552282...
# entertainment F                                                  1219.0
#               M                       1338277019470208204653081919488.0
# executive     F                                                164648.0
# ...

# %%
# For each occupation present the percentage of women and men
percentage_of_women_and_men = users_df.groupby(['occupation','gender'])['gender'].count()
percentage_of_women_and_men_df = pd.DataFrame(percentage_of_women_and_men)
percentage_of_women_and_men_df
# Out:
#                       gender
# occupation    gender
# administrator F           36
#               M           43
# artist        F           13
#               M           15
# doctor        M            7
# educator      F           26
#               M           69
# engineer      F            2
#               M           65
# entertainment F            2
#               M           16
# executive     F            3
#               M           29
# healthcare    F           11
#               M            5
# homemaker     F            6
#               M            1
# lawyer        F            2
#               M           10
# librarian     F           29
#               M           22
# marketing     F           10
#               M           16
# none          F            4
#               M            5
# other         F           36
#               M           69
# programmer    F            6
#               M           60
# retired       F            1
# ...

# %%
# New Project

# %%
# Alcohol_Consumption
drinks_df = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv')
drinks_df
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...

# %%
# Which continent drinks more beer on average?
drinks_df.groupby('continent')['total_litres_of_pure_alcohol'].mean().idxmax()
# Out:
# 'EU'

# %%
# For each continent print the statistics for wine consumption.
drinks_df.groupby('continent')['wine_servings'].describe()
# Out:
#            count        mean        std  min   25%    50%     75%    max
# continent
# AF          53.0   16.264151  38.846419  0.0   1.0    2.0   13.00  233.0
# AS          44.0    9.068182  21.667034  0.0   0.0    1.0    8.00  123.0
# EU          45.0  142.222222  97.421738  0.0  59.0  128.0  195.00  370.0
# OC          16.0   35.625000  64.555790  0.0   1.0    8.5   23.25  212.0
# SA          12.0   62.416667  88.620189  1.0   3.0   12.0   98.50  221.0

# %%
# Print the mean alcohol consumption per continent for every column
mean_alcohol_consumption = drinks_df.groupby('continent')['total_litres_of_pure_alcohol'].mean()
mean_alcohol_consumption_df = pd.DataFrame(mean_alcohol_consumption)
mean_alcohol_consumption_df
# Out:
#            total_litres_of_pure_alcohol
# continent
# AF                             3.007547
# AS                             2.170455
# EU                             8.617778
# OC                             3.381250
# SA                             6.308333

# %%
# Print the median alcohol consumption per continent for every column
median_alcohol_consumption = drinks_df.groupby('continent')['beer_servings'].median()
median_alcohol_consumption_df = pd.DataFrame(mean_alcohol_consumption)
median_alcohol_consumption_df
# Out:
#            total_litres_of_pure_alcohol
# continent
# AF                             3.007547
# AS                             2.170455
# EU                             8.617778
# OC                             3.381250
# SA                             6.308333

# %%
# Step 8. Print the mean, min and max values for spirit consumption
drinks_df.groupby('continent')['spirit_servings'].describe()
# Out:
#            count        mean        std   min    25%    50%     75%    max
# continent
# AF          53.0   16.339623  28.102794   0.0   1.00    3.0   19.00  152.0
# AS          44.0   60.840909  84.362160   0.0   1.00   16.0   98.00  326.0
# EU          45.0  132.555556  77.589115   0.0  81.00  122.0  173.00  373.0
# OC          16.0   58.437500  70.504817   0.0  18.00   37.0   65.25  254.0
# SA          12.0  114.750000  77.077440  25.0  65.75  108.5  148.75  302.0

# %%
# New Section

# %%
# 04_Apply

# %%
# US_Crime_Rates
crime_df = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/US_Crime_Rates/US_Crime_Rates_1960_2014.csv')
crime_df
# Out:
#     Year  Population     Total  Violent  Property  Murder  Forcible_Rape  \
# 0   1960   179323175   3384200   288460   3095700    9110          17190
# 1   1961   182992000   3488000   289390   3198600    8740          17220
# 2   1962   185771000   3752200   301510   3450700    8530          17550
# 3   1963   188483000   4109500   316970   3792500    8640          17650
# 4   1964   191141000   4564600   364220   4200400    9360          21420
# 5   1965   193526000   4739400   387390   4352000    9960          23410
# 6   1966   195576000   5223500   430180   4793300   11040          25820
# 7   1967   197457000   5903400   499930   5403500   12240          27620
# 8   1968   199399000   6720200   595010   6125200   13800          31670
# 9   1969   201385000   7410900   661870   6749000   14760          37170
# 10  1970   203235298   8098000   738820   7359200   16000          37990
# 11  1971   206212000   8588200   816500   7771700   17780          42260
# ...

# %%
# What is the type of the columns?
crime_df.dtypes
# Out:
# Year                  int64
# Population            int64
# Total                 int64
# Violent               int64
# Property              int64
# Murder                int64
# Forcible_Rape         int64
# Robbery               int64
# Aggravated_assault    int64
# Burglary              int64
# Larceny_Theft         int64
# Vehicle_Theft         int64
# dtype: object

# %%
# Convert the type of the column Year to datetime64
crime_df['Year'] = pd.to_datetime(crime_df['Year'])
crime_df['Year'].dtypes
# Out:
# dtype('<M8[ns]')

# %%
# Set the Year column as the index of the dataframe
crime_df['Year'] = crime_df['Year'].astype(int)
crime_df.set_index('Year',inplace = True)
crime_df
# Out:
#       Population     Total  Violent  Property  Murder  Forcible_Rape  Robbery  \
# Year
# 1960   179323175   3384200   288460   3095700    9110          17190   107840
# 1961   182992000   3488000   289390   3198600    8740          17220   106670
# 1962   185771000   3752200   301510   3450700    8530          17550   110860
# 1963   188483000   4109500   316970   3792500    8640          17650   116470
# 1964   191141000   4564600   364220   4200400    9360          21420   130390
# 1965   193526000   4739400   387390   4352000    9960          23410   138690
# 1966   195576000   5223500   430180   4793300   11040          25820   157990
# 1967   197457000   5903400   499930   5403500   12240          27620   202910
# 1968   199399000   6720200   595010   6125200   13800          31670   262840
# 1969   201385000   7410900   661870   6749000   14760          37170   298850
# 1970   203235298   8098000   738820   7359200   16000          37990   349860
# ...

# %%
# Delete the Total colum
crime_df.drop(columns=['Total'],inplace = True)
crime_df
# Out:
#       Population  Violent  Property  Murder  Forcible_Rape  Robbery  \
# Year
# 1960   179323175   288460   3095700    9110          17190   107840
# 1961   182992000   289390   3198600    8740          17220   106670
# 1962   185771000   301510   3450700    8530          17550   110860
# 1963   188483000   316970   3792500    8640          17650   116470
# 1964   191141000   364220   4200400    9360          21420   130390
# 1965   193526000   387390   4352000    9960          23410   138690
# 1966   195576000   430180   4793300   11040          25820   157990
# 1967   197457000   499930   5403500   12240          27620   202910
# 1968   199399000   595010   6125200   13800          31670   262840
# 1969   201385000   661870   6749000   14760          37170   298850
# 1970   203235298   738820   7359200   16000          37990   349860
# 1971   206212000   816500   7771700   17780          42260   387700
# 1972   208230000   834900   7413900   18670          46850   376290
# ...

# %%
# Group the year by decades and sum the values
def get_decade(year):
    return (year // 10) * 10
crime_df['total'] = crime_df['Violent'] + crime_df['Property'] + crime_df['Murder'] + crime_df['Forcible_Rape'] + crime_df['Aggravated_assault'] + crime_df['Burglary'] + crime_df['Larceny_Theft'] + crime_df['Vehicle_Theft']
crime_df.groupby(get_decade)['total'].sum()
# Out:
# Year
# 1960     96958150
# 1970    197824350
# 1980    256863594
# 1990    267413800
# 2000    225598417
# 2010     98521983
# Name: total, dtype: int64

# %%
# What is the most dangerous decade to live in the US?
crime_df.groupby(get_decade)['total'].sum().idxmax()
# Out:
# 1990

# %%
# New Project

# %%
# Students_Alcohol_Consumption
students_df = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/Students_Alcohol_Consumption/student-mat.csv')
students_df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
# For the purpose of this exercise slice the dataframe from 'school' until the 'guardian' column
students_df.loc[: , : 'guardian']
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      reason guardian
# 0    course   mother
# ...

# %%
# Create a lambda function that will capitalize strings
capitalize_string = lambda x: x.capitalize()

# %%
# Step 6. Capitalize both Mjob and Fjob
students_df['Mjob'] = students_df['Mjob'].apply(capitalize_string)
students_df['Fjob'] = students_df['Fjob'].apply(capitalize_string)
students_df[['Mjob','Fjob']]
# Out:
#          Mjob      Fjob
# 0     At_home   Teacher
# 1     At_home     Other
# 2     At_home     Other
# 3      Health  Services
# 4       Other     Other
# ..        ...       ...
# 390  Services  Services
# 391  Services  Services
# 392     Other     Other
# 393  Services     Other
# 394     Other   At_home
#
# [395 rows x 2 columns]

# %%
# Print the last elements of the data set
students_df.iloc[-1: , :]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu   Mjob     Fjob  ...  \
# 394     MS   M   19       U     LE3       T     1     1  Other  At_home  ...
#
#     famrel freetime  goout  Dalc  Walc health absences G1 G2 G3
# 394      3        2      3     3     3      5        5  8  9  9
#
# [1 rows x 33 columns]

# %%
# Create a function called majority that returns a boolean value to a new column called legal_drinker 
# (Consider majority as older than 17 years old)
def majority(age):
    return age > 17
students_df['legal_drinker'] = students_df['age'].apply(majority)
students_df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   At_home   Teacher
# 1       GP   F   17       U     GT3       T     1     1   At_home     Other
# 2       GP   F   15       U     LE3       T     1     1   At_home     Other
# 3       GP   F   15       U     GT3       T     4     2    Health  Services
# 4       GP   F   16       U     GT3       T     3     3     Other     Other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  Services  Services
# 391     MS   M   17       U     LE3       T     3     1  Services  Services
# 392     MS   M   21       R     GT3       T     1     1     Other     Other
# 393     MS   M   18       R     LE3       T     3     2  Services     Other
# 394     MS   M   19       U     LE3       T     1     1     Other   At_home
#
# ...

# %%
# Multiply every number of the dataset by 10. 
students_df.apply(lambda x: x * 10 if pd.api.types.is_numeric_dtype(x) else x)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F  180       U     GT3       A    40    40   At_home   Teacher
# 1       GP   F  170       U     GT3       T    10    10   At_home     Other
# 2       GP   F  150       U     LE3       T    10    10   At_home     Other
# 3       GP   F  150       U     GT3       T    40    20    Health  Services
# 4       GP   F  160       U     GT3       T    30    30     Other     Other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M  200       U     LE3       A    20    20  Services  Services
# 391     MS   M  170       U     LE3       T    30    10  Services  Services
# 392     MS   M  210       R     GT3       T    10    10     Other     Other
# 393     MS   M  180       R     LE3       T    30    20  Services     Other
# 394     MS   M  190       U     LE3       T    10    10     Other   At_home
#
# ...

# %%
# New Section

# %%
# 05_Merge

# %%
# Housing Market

# %%
# Create 3 differents Series, each of length 100, as follows: 
# 1. The first a random number from 1 to 4 
# 2. The second a random number from 1 to 3
# 3. The third a random number from 10,000 to 30,000
import numpy as np
series1 = pd.Series(np.random.uniform(1, 5, 100))
series2 = pd.Series(np.random.randint(1, 4, 100)) 
series3 = pd.Series(np.random.randint(10000, 30001, 100))

# %%
# Let's create a DataFrame by joinning the Series by column
series_df = pd.concat([series1,series2,series3] , axis = 1)
series_df.columns = ['series1','series2','series3']
series_df
# Out:
#      series1  series2  series3
# 0   1.871851        2    13415
# 1   1.440152        3    11235
# 2   1.006189        3    14277
# 3   2.719466        1    12456
# 4   2.744279        1    12178
# ..       ...      ...      ...
# 95  3.810804        1    22293
# 96  1.332053        1    15033
# 97  2.207134        2    22857
# 98  3.898669        1    22331
# 99  3.759800        3    13552
#
# [100 rows x 3 columns]

# %%
# Change the name of the columns to bedrs, bathrs, price_sqr_meter
series_df.rename(columns={'series1' :'bedrs' , 'series2' : 'bathrs' , 'series3' : 'price_sqr_meter' } , inplace = True)
series_df
# Out:
#        bedrs  bathrs  price_sqr_meter
# 0   1.871851       2            13415
# 1   1.440152       3            11235
# 2   1.006189       3            14277
# 3   2.719466       1            12456
# 4   2.744279       1            12178
# ..       ...     ...              ...
# 95  3.810804       1            22293
# 96  1.332053       1            15033
# 97  2.207134       2            22857
# 98  3.898669       1            22331
# 99  3.759800       3            13552
#
# [100 rows x 3 columns]

# %%
# Create a one column DataFrame with the values of the 3 Series and assign it to 'bigcolumn'
big_column = pd.concat([series1 , series2 , series3],ignore_index=True )
big_column_df = pd.DataFrame({'big column':big_column})
big_column_df
# Out:
#        big column
# 0        1.871851
# 1        1.440152
# 2        1.006189
# 3        2.719466
# 4        2.744279
# ..            ...
# 295  22293.000000
# 296  15033.000000
# 297  22857.000000
# 298  22331.000000
# 299  13552.000000
#
# [300 rows x 1 columns]

# %%
# New Project

# %%
# Fictitous Names

raw_data_1 = {
        'subject_id': ['1', '2', '3', '4', '5'],
        'first_name': ['Alex', 'Amy', 'Allen', 'Alice', 'Ayoung'], 
        'last_name': ['Anderson', 'Ackerman', 'Ali', 'Aoni', 'Atiches']}

data1_df = pd.DataFrame(raw_data_1) 
data1_df
# Out:
#   subject_id first_name last_name
# 0          1       Alex  Anderson
# 1          2        Amy  Ackerman
# 2          3      Allen       Ali
# 3          4      Alice      Aoni
# 4          5     Ayoung   Atiches

# %%
raw_data_2 = {
        'subject_id': ['4', '5', '6', '7', '8'],
        'first_name': ['Billy', 'Brian', 'Bran', 'Bryce', 'Betty'], 
        'last_name': ['Bonder', 'Black', 'Balwner', 'Brice', 'Btisan']}

data2_df = pd.DataFrame(raw_data_2) 
data2_df
# Out:
#   subject_id first_name last_name
# 0          4      Billy    Bonder
# 1          5      Brian     Black
# 2          6       Bran   Balwner
# 3          7      Bryce     Brice
# 4          8      Betty    Btisan

# %%
raw_data_3 = {
        'subject_id': ['1', '2', '3', '4', '5', '7', '8', '9', '10', '11'],
        'test_id': [51, 15, 15, 61, 16, 14, 15, 1, 61, 16]}


data3_df = pd.DataFrame(raw_data_3)

# %%
# Join the two dataframes along rows and assign all_data
all_data = pd.concat([data1_df,data2_df], axis = 0)
all_data
# Out:
#   subject_id first_name last_name
# 0          1       Alex  Anderson
# 1          2        Amy  Ackerman
# 2          3      Allen       Ali
# 3          4      Alice      Aoni
# 4          5     Ayoung   Atiches
# 0          4      Billy    Bonder
# 1          5      Brian     Black
# 2          6       Bran   Balwner
# 3          7      Bryce     Brice
# 4          8      Betty    Btisan

# %%
# Join the two dataframes along columns and assing to all_data_col
two_dataframes_along_columns = pd.concat([data2_df,data3_df] , axis = 1)
two_dataframes_along_columns
# Out:
#   subject_id first_name last_name subject_id  test_id
# 0          4      Billy    Bonder          1       51
# 1          5      Brian     Black          2       15
# 2          6       Bran   Balwner          3       15
# 3          7      Bryce     Brice          4       61
# 4          8      Betty    Btisan          5       16
# 5        NaN        NaN       NaN          7       14
# 6        NaN        NaN       NaN          8       15
# 7        NaN        NaN       NaN          9        1
# 8        NaN        NaN       NaN         10       61
# 9        NaN        NaN       NaN         11       16

# %%
# Print data3
data3_df
# Out:
#   subject_id  test_id
# 0          1       51
# 1          2       15
# 2          3       15
# 3          4       61
# 4          5       16
# 5          7       14
# 6          8       15
# 7          9        1
# 8         10       61
# 9         11       16

# %%
# Merge all_data and data3 along the subject_id value
all_data_and_data3_df = pd.merge(all_data,data3_df , on = 'subject_id')
all_data_and_data3_df
# Out:
#   subject_id first_name last_name  test_id
# 0          1       Alex  Anderson       51
# 1          2        Amy  Ackerman       15
# 2          3      Allen       Ali       15
# 3          4      Alice      Aoni       61
# 4          4      Billy    Bonder       61
# 5          5     Ayoung   Atiches       16
# 6          5      Brian     Black       16
# 7          7      Bryce     Brice       14
# 8          8      Betty    Btisan       15

# %%
# Merge only the data that has the same 'subject_id' on both data1 and data2
same_data_df = pd.merge(data1_df , data2_df, on = 'subject_id')
same_data_df
# Out:
#   subject_id first_name_x last_name_x first_name_y last_name_y
# 0          4        Alice        Aoni        Billy      Bonder
# 1          5       Ayoung     Atiches        Brian       Black

# %%
# Merge all values in data1 and data2, with matching records from both sides where available.
all_values = pd.merge(data1_df , data2_df, on = 'subject_id', how='outer')
all_values
# Out:
#   subject_id first_name_x last_name_x first_name_y last_name_y
# 0          1         Alex    Anderson          NaN         NaN
# 1          2          Amy    Ackerman          NaN         NaN
# 2          3        Allen         Ali          NaN         NaN
# 3          4        Alice        Aoni        Billy      Bonder
# 4          5       Ayoung     Atiches        Brian       Black
# 5          6          NaN         NaN         Bran     Balwner
# 6          7          NaN         NaN        Bryce       Brice
# 7          8          NaN         NaN        Betty      Btisan

# %%
# New Project

# %%
# Auto_MPG

# %%
cars1_df = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/05_Merge/Auto_MPG/cars1.csv')
cars1_df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 193  24.0          6           200         81    3012          17.6     76
# 194  22.5          6           232         90    3085          17.6     76
# 195  29.0          4            85         52    2035          22.2     76
# 196  24.5          4            98         60    2164          22.1     76
# 197  29.0          4            90         70    1937          14.2     76
#
# ...

# %%
cars2_df = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/05_Merge/Auto_MPG/cars2.csv')
cars2_df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    33.0          4            91         53    1795          17.4     76
# 1    20.0          6           225        100    3651          17.7     76
# 2    18.0          6           250         78    3574          21.0     76
# 3    18.5          6           250        110    3645          16.2     76
# 4    17.5          6           258         95    3193          17.8     76
# ..    ...        ...           ...        ...     ...           ...    ...
# 195  27.0          4           140         86    2790          15.6     82
# 196  44.0          4            97         52    2130          24.6     82
# 197  32.0          4           135         84    2295          11.6     82
# 198  28.0          4           120         79    2625          18.6     82
# 199  31.0          4           119         82    2720          19.4     82
#
#      origin                 car
# 0         3         honda civic
# ...

# %%
# Oops, it seems our first dataset has some unnamed blank columns, fix cars1
cars1_df.drop(columns = ['Unnamed: 9' , 'Unnamed: 10','Unnamed: 11','Unnamed: 12','Unnamed: 13'], inplace= True)
cars1_df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 193  24.0          6           200         81    3012          17.6     76
# 194  22.5          6           232         90    3085          17.6     76
# 195  29.0          4            85         52    2035          22.2     76
# 196  24.5          4            98         60    2164          22.1     76
# 197  29.0          4            90         70    1937          14.2     76
#
#      origin                        car
# ...

# %%
# What is the number of observations in each dataset?
print(cars1_df.shape[0])
print(cars2_df.shape[0])
# Out:
# 198
# 200

# %%
# Join cars1 and cars2 into a single DataFrame called cars
merged_cars_df = pd.concat([cars1_df,cars1_df] , ignore_index= True)
merged_cars_df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 391  24.0          6           200         81    3012          17.6     76
# 392  22.5          6           232         90    3085          17.6     76
# 393  29.0          4            85         52    2035          22.2     76
# 394  24.5          4            98         60    2164          22.1     76
# 395  29.0          4            90         70    1937          14.2     76
#
#      origin                        car
# ...

# %%
# Step 7. Oops, there is a column missing, called owners. Create a random number Series from 15,000 to 73,000
owners = pd.Series(np.random.uniform(15000 ,73000,size  = len(merged_cars_df)))

# %%
# Add the column owners to cars
merged_cars_df['cars'] = owners
merged_cars_df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 391  24.0          6           200         81    3012          17.6     76
# 392  22.5          6           232         90    3085          17.6     76
# 393  29.0          4            85         52    2035          22.2     76
# 394  24.5          4            98         60    2164          22.1     76
# 395  29.0          4            90         70    1937          14.2     76
#
#      origin                        car          cars
# ...

# %%
# New Section

# %%
# 07_Visualization

# %%
# Titanic_Desaster
titanic_df = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Titanic_Desaster/train.csv')
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Set PassengerId as the index 
# titanic_df.set_index('PassengerId', inplace=True)

# %%
import matplotlib.pyplot as plt

# %%
# Create a pie chart presenting the male/female proportion

gender_counts = titanic_df['Sex'].value_counts()
plt.pie(gender_counts , labels = gender_counts.index, autopct = '%0.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7b9ce89432b0>,
# ...
#  [Text(-0.4919454136803954, 0.9838646807152012, 'male'),
#   Text(0.4919455057964525, -0.9838646346559433, 'female')],
#  [Text(-0.2683338620074884, 0.5366534622082915, '64.8%'),
#   Text(0.26833391225261044, -0.53665343708506, '35.2%')])

# %%
# Create a scatterplot with the Fare payed and the Age, differ the plot color by gender

colors = {"male": "red", "female": "blue"}
plt.scatter(titanic_df['Fare'],titanic_df['Age'], c=titanic_df["Sex"].apply(lambda x: colors[x]))

# %%
# Create a scatterplot with the Fare payed and the Age, differ the plot color by gender


colors = {"male": "red", "female": "blue"}
plt.scatter(titanic_df['Fare'] ,titanic_df['Sex'] , c=titanic_df["Sex"].apply(lambda x: colors[x]))

# %%
# How many people survived

titanic_df['Survived'].sum()
# Out:
# 342

# %%
# Create a histogram with the Fare payed

plt.hist(titanic_df['Fare'])
# Out:
# (array([732., 106.,  31.,   2.,  11.,   6.,   0.,   0.,   0.,   3.]),
#  array([  0.     ,  51.23292, 102.46584, 153.69876, 204.93168, 256.1646 ,
#         307.39752, 358.63044, 409.86336, 461.09628, 512.3292 ]),
#  <BarContainer object of 10 artists>)

# %%
# New Project

# %%
# Tips

tips = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Tips/tips.csv')
tips
# Out:
#      Unnamed: 0  total_bill   tip     sex smoker   day    time  size
# 0             0       16.99  1.01  Female     No   Sun  Dinner     2
# 1             1       10.34  1.66    Male     No   Sun  Dinner     3
# 2             2       21.01  3.50    Male     No   Sun  Dinner     3
# 3             3       23.68  3.31    Male     No   Sun  Dinner     2
# 4             4       24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...         ...   ...     ...    ...   ...     ...   ...
# 239         239       29.03  5.92    Male     No   Sat  Dinner     3
# 240         240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241         241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242         242       17.82  1.75    Male     No   Sat  Dinner     2
# 243         243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 8 columns]

# %%
# Delete the Unnamed 0 column

tips.drop(columns = ['Unnamed: 0'] , axis = 1)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# Plot the total_bill column histogram
plt.hist(tips['total_bill'])
# Out:
# (array([ 7., 42., 68., 51., 31., 19., 12.,  7.,  3.,  4.]),
#  array([ 3.07 ,  7.844, 12.618, 17.392, 22.166, 26.94 , 31.714, 36.488,
#         41.262, 46.036, 50.81 ]),
#  <BarContainer object of 10 artists>)

# %%
# Create a scatter plot presenting the relationship between total_bill and tip

plt.scatter(tips['total_bill'] , tips['tip'])

# %%
# Create one image with the relationship of total_bill, tip and size

# %%
# Present the relationship between days and total_bill value

plt.scatter(tips['day'] , tips['total_bill'])

# %%
# Create a scatter plot with the day as the y-axis and tip as the x-axis, differ the dots by sex

colors = {'Male' : 'red' , 'Female' : 'blue'}

plt.scatter(tips['day'] , tips['tip'] ,c=tips["sex"].apply(lambda x: colors[x]))
plt.ylabel('day')
plt.xlabel('tip')
plt.show()

# %%
# Create a box plot presenting the total_bill per day differetiation the time (Dinner or Lunch)

plt.boxplot(tips['total_bill'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7b9ccee50640>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7b9ccee50b80>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7b9ccee503a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7b9ccee510c0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7b9ccee51360>],
#  'means': []}

# %%
# Create two histograms of the tip value based for Dinner and Lunch. They must be side by side.

plt.subplot(1,2,1)
plt.hist(tips[tips['time'] == 'Dinner'].value_counts())
plt.title('Dinner')

plt.subplot(1,2,2)
plt.hist(tips[tips['time'] == 'Lunch'].value_counts())
plt.title('Lunch')

plt.subplots_adjust(left = 3 , right = 5)

# %%
# Create two scatterplots graphs, one for Male and another for Female, presenting the total_bill value and tip relationship, 
# differing by smoker or no smokerThey must be side by side 

colors = {'Yes' : 'red' , 'No' : 'blue'}
plt.subplot(1,2,1)
male_df = tips[tips['sex'] == 'Male']
plt.title('Male')
plt.xlabel('total_bill')
plt.ylabel('smoker')
plt.scatter(male_df['total_bill'],male_df['smoker'],c=male_df["smoker"].apply(lambda x: colors[x]))

plt.subplot(1,2,2)
female_df = tips[tips['sex'] == 'Female']
plt.title('female')
plt.xlabel('total_bill')
plt.ylabel('smoker')
plt.scatter(female_df['total_bill'],female_df['smoker'],c=female_df["smoker"].apply(lambda x: colors[x]))

plt.subplots_adjust(left = 3 , right = 5)

# %%
# New Project

# %%
# Scores
data = {
    'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'],
    'last_name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze'],
    'age': [42, 52, 36, 24, 73],
    'female': [0, 1, 1, 0, 1],
    'preTestScore': [4, 24, 31, 2, 3],
    'postTestScore': [25, 94, 57, 62, 70]
}
data_df = pd.DataFrame(data)
data_df
# Out:
#   first_name last_name  age  female  preTestScore  postTestScore
# 0      Jason    Miller   42       0             4             25
# 1      Molly  Jacobson   52       1            24             94
# 2       Tina       Ali   36       1            31             57
# 3       Jake    Milner   24       0             2             62
# 4        Amy     Cooze   73       1             3             70

# %%
# Create a Scatterplot of preTestScore and postTestScore, with the size of each point determined by age

plt.scatter(data_df['preTestScore'], data_df['postTestScore'], s=data_df['age'] * 3 , color = 'red')

# Set labels and title
plt.xlabel('preTestScore')
plt.ylabel('postTestScore')
plt.title('preTestScore vs. postTestScore')
# Out:
# Text(0.5, 1.0, 'preTestScore vs. postTestScore')

# %%
# Create a Scatterplot of preTestScore and postTestScore.
# This time the size should be 4.5 times the postTestScore and the color determined by sex
colors = {0 : 'blue' , 1 : 'red'}
plt.scatter(data_df['preTestScore'], data_df['postTestScore'], s = data_df['postTestScore'] * 4.5 ,c=data_df["female"].apply(lambda x: colors[x]))

# Set labels and title
plt.xlabel('preTestScore')
plt.ylabel('postTestScore')
plt.title('preTestScore vs. postTestScore')
# Out:
# Text(0.5, 1.0, 'preTestScore vs. postTestScore')

# %%
# New Project

# %%
# Online_Retail

online_rt = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Online_Retail/Online_Retail.csv' , encoding = 'latin1')
online_rt
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
# Create a histogram with the 10 countries that have the most 'Quantity' ordered except UK

online_rt = online_rt[online_rt['Country'] != 'United Kingdom']
top_10_countries = online_rt.groupby('Country')['Quantity'].sum().sort_values(ascending=False)
top_10_countries = top_10_countries.head(10)

plt.bar(top_10_countries.index, top_10_countries.values, color='skyblue')
plt.xlabel('Countries')
plt.ylabel('Total Quantity Ordered')
plt.title('Top 10 Countries with the Most Quantity Ordered')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
# Exclude negative Quantity entries

online_rt.drop(online_rt[online_rt['Quantity'] < 0].index ,axis = 0 , inplace = True)
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 26        536370     22728        ALARM CLOCK BAKELIKE PINK        24
# 27        536370     22727        ALARM CLOCK BAKELIKE RED         24
# 28        536370     22726       ALARM CLOCK BAKELIKE GREEN        12
# 29        536370     21724  PANDA AND BUNNIES STICKER SHEET        12
# 30        536370     21883                 STARS GIFT TAPE         24
# ...          ...       ...                              ...       ...
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#           InvoiceDate  UnitPrice  CustomerID Country
# 26       12/1/10 8:45       3.75     12583.0  France
# ...

# %%
# Create a scatterplot with the Quantity per UnitPrice by CustomerID for the top 3 Countries (except UK)

top_countries = online_rt["Country"].value_counts().nlargest(3).index.tolist()

filtered_data = online_rt[online_rt["Country"].isin(top_countries)]

filtered_data["Quantity_per_UnitPrice"] = filtered_data["Quantity"] / filtered_data["UnitPrice"]

plt.scatter(filtered_data["CustomerID"], filtered_data["Quantity_per_UnitPrice"])
plt.xlabel("CustomerID")
plt.ylabel("Quantity per UnitPrice")
plt.title("Quantity per UnitPrice by CustomerID for Top 3 Countries (except UK)")

plt.show()
# Out:
# /tmp/ipykernel_47/1862853603.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data["Quantity_per_UnitPrice"] = filtered_data["Quantity"] / filtered_data["UnitPrice"]

# %%
# New Project

# %%
# Chipotle
chipo = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv', sep = '\t')
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
# See the first 10 entries

chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
# create a histogram of the top 5 items bought

chipo_5 = chipo.groupby('item_name')['quantity'].sum().sort_values(ascending=False)
chipo_5 = chipo_5.head(5)

plt.hist(chipo_5)
plt.show()
